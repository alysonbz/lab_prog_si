# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/habacuquidoglas/aula10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#questão 1
import matplotlib.pyplot as plt
year = [1950,1970,1990,2010]
pop = [2.519,3.692,5.263,6.922]
plt.plot(year,pop)
plt.show()

# %%
#questão 2
year[-1]
pop[-1]
print(year[-1],pop[-1])
# Out:
# 2010 6.922

# %%
ano = [2020,2021,2022,2023,2024,2025]
peso = [70,75,80,88,78,99]
plt.scatter(ano,peso)
plt.show()

# %%
#questão 1 a 3
plt.plot(ano,peso)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(ano,peso)
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
data = load_iris()
df = pd.DataFrame(data.data,columns=data.feature_names)
df["target"] = data.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
plt.scatter(df["petal length (cm)"],df["sepal width (cm)"],c=df["target"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df["sepal length (cm)"],df["petal width (cm)"],c=df["target"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df["petal length (cm)"],df["petal width (cm)"],c=df["target"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df["sepal length (cm)"],df["sepal width (cm)"],c=df["target"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df["petal length (cm)"],df["sepal length (cm)"],c=df["target"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df["petal width (cm)"],df["sepal width (cm)"],c=df["target"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
turma = [ 18,18,18,18,19,19,18,20,5,18,18]
plt.hist(turma, bins=35)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(df["sepal width (cm)"], bins=100)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#questão 1
idades=[18,18,18,18,18,18,18,18,18,18,19,19,21,20,18,18,18,18,18,18,18,18,18,18]
plt.hist(idades, bins=5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.clf()
idades=[18,18,18,18,18,18,18,18,18,18,19,19,21,20,18,18,18,18,18,18,18,18,18,18]
plt.hist(idades, bins=5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
idades=[18,18,18,18,18,18,18,18,18,18,19,19,21,20,18,18,18,18,18,18,18,18,18,18]
plt.hist(idades, bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.clf()
idades=[18,18,18,18,18,18,18,18,18,18,19,19,21,20,18,18,18,18,18,18,18,18,18,18]
plt.hist(idades, bins=5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
