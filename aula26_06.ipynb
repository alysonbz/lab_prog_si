# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/kauan_lima/aula26_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
year= [1950, 1970, 1990, 2010]
pop= [2.519, 3.692, 5.263, 6.972]
plt.plot(year, pop)
plt.xlabel('year')
plt.ylabel('population')
plt.title('World Population Projections')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ano=[2020, 2021, 2022, 2023, 2024, 2025]
peso=[82, 82, 80, 69, 75, 78]
plt.plot(ano, peso)
plt.title('meu peso ao decorrer dos anos')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y= [1950, 1970, 1990, 2010]
p= [2.519, 3.692, 5.263, 6.972]
plt.scatter(year, pop)
plt.xlabel('year')
plt.ylabel('population')
plt.title('World Population Projections')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a=[2020, 2021, 2022, 2023, 2024, 2025]
pe=[82, 82, 80, 69, 75, 78]
plt.scatter(ano, peso)
plt.xlabel('ano')
plt.ylabel('peso')
plt.title('meu peso ao decorrer dos anos')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Pratique

# %%
#1
print(year[-1])
print(pop[-1])
# Out:
# 2010
# 6.972

# %%
#2
print(ano[-1])
print(peso[-1])
# Out:
# 2025
# 78

# %%
#3
ano=[2020, 2021, 2022, 2023, 2024, 2025]
peso=[82, 82, 80, 69, 75, 78]
plt.plot(ano, peso)
plt.xlabel('ano')
plt.ylabel('peso')
plt.title('meu peso ao decorrer dos anos')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#4
ano=[2020, 2021, 2022, 2023, 2024, 2025]
peso=[82, 82, 80, 69, 75, 78]
plt.scatter(ano, peso)
plt.xscale('log')
plt.title('meu peso ao decorrer dos anos')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#5
ano=[2020, 2021, 2022, 2023, 2024, 2025]
peso=[82, 82, 80, 69, 75, 78]
plt.scatter(ano, peso)
plt.xlabel('ano')
plt.ylabel('peso')
plt.title('meu peso ao decorrer dos anos')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
data= load_iris()
df=pd.DataFrame(data.data, columns=data.feature_names)
df['target']=data.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
from matplotlib import pyplot as plt
plt.scatter(df['sepal length (cm)'], df['petal width (cm)'], c=df['target'])

# %%
plt.scatter(df['petal length (cm)'], df['sepal width (cm)'], c=df['target'])

# %%
plt.scatter(df['petal length (cm)'], df['petal width (cm)'], c=df['target'])

# %%
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'])

# %%
plt.scatter(df['sepal width (cm)'], df['petal width (cm)'], c=df['target'])

# %%
plt.scatter(df['petal width (cm)'], df['sepal width (cm)'], c=df['target'])

# %%
plt.scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['target'])

# %%
plt.scatter(df['petal length (cm)'], df['sepal length (cm)'], c=df['target'])

# %%
plt.scatter(df['petal length (cm)'], df['petal length (cm)'], c=df['target'])

# %%
plt.scatter(df['sepal length (cm)'], df['sepal length (cm)'], c=df['target'])

# %%
import matplotlib.pyplot as plt

# %%
idad=[18, 18, 18, 19, 19, 18, 20, 5, 18, 18]
plt.hist(idades, bins=30)
plt.show()

# %%
plt.hist(df['sepal width (cm)'], bins=30)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Pratique

# %%
#1
idades=[18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 20, 20 ,20, 19, 19, 19, 19, 18, 18, 18, 18, 18]
plt.hist(idades, bins=30)
plt.show()

# %%
#2
idades=[18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 20, 20 ,20, 19, 19, 19, 19, 18, 18, 18, 18, 18]
plt.hist(idades, bins=5)
plt.show()
plt.clf()
idades=[18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 20, 20 ,20, 19, 19, 19, 19, 18, 18, 18, 18, 18]
plt.hist(idades, bins=20)
plt.show()
