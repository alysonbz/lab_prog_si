# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/saulo_brito/hj1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

# %%
values = [0,0.6,1.4,1.6,2.2,2.5,2.6,3.2,3.5,3.9,4.2,6]
plt.hist(values, bins=3)
plt.show()

# %%
idade =

# %%
#atividade 2

# %%
idade = [18,18,18,18,19,19,18,20,18,18,21]

# %%
plt.hist(idade, bins=3)
plt.show()

# %%
#atividae 3

# %%
idades = [18,21,22,19,45,31,34,25,29,40,18,23,37,21,30,28,19,33,26,38]

# %%
plt.hist(idades, bins=5)
plt.title("histograma de 5 bins")
plt.show()

# %%
plt.hist(idades, bins=20)
plt.title("histograma de 20 bins")
plt.show()
