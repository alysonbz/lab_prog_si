# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/Emanuel_Oliveira/aula14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
brics = pd.read_csv("/content/brics.csv", index_col = 0)
for val in brics:
  print(val)
# Out:
# country
# capital
# area
# population

# %%
import pandas as pd
brics = pd.read_csv("/content/brics.csv", index_col = 0)
for lab, row in brics.iterrows():
  print(lab + ": "+ row["capital"])
# Out:
# BR: Brasilia
# RU: Moscow
# IN: New Delhi
# CH: Beijing
# SA: Pretoria

# %%
import pandas as pd
brics = pd.read_csv("/content/brics.csv", index_col = 0)
for lab, row in brics.iterrows():
  brics.loc[lab,"name_length"] = len(row["country"])
print(brics)
# Out:
#                  country    capital    area  population  name_length
# country_ab
# BR                Brazil   Brasilia   8.516      200.40          6.0
# RU                Russia     Moscow  17.100      143.50          6.0
# IN                 India  New Delhi   3.286     1252.00          5.0
# CH                 China    Beijing   9.597     1357.00          5.0
# SA          South Africa   Pretoria   1.221       52.98         12.0

# %%
import pandas as pd
brics = pd.read_csv("/content/brics.csv", index_col = 0)
brics["name_length"] = brics["country"].apply(len)
print(brics)
# Out:
#                  country    capital    area  population  name_length
# country_ab
# BR                Brazil   Brasilia   8.516      200.40            6
# RU                Russia     Moscow  17.100      143.50            6
# IN                 India  New Delhi   3.286     1252.00            5
# CH                 China    Beijing   9.597     1357.00            5
# SA          South Africa   Pretoria   1.221       52.98           12

# %%
def check_area(area):
  if area < 8:
    return "pais pequeno"
  else:
    return "pais grande"
brics["country_size"] = brics["area"].apply(check_area)
brics
# Out:
#                  country    capital    area  population  name_length  \
# country_ab
# BR                Brazil   Brasilia   8.516      200.40            6
# RU                Russia     Moscow  17.100      143.50            6
# IN                 India  New Delhi   3.286     1252.00            5
# CH                 China    Beijing   9.597     1357.00            5
# SA          South Africa   Pretoria   1.221       52.98           12
#
#             country_size
# country_ab
# BR           pais grande
# RU           pais grande
# IN          pais pequeno
# CH           pais grande
# SA          pais pequeno

# %% [markdown]
# ![Captura de tela 2025-07-17 105916.png](data:image/png;base64,...)

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv("/content/cars.csv", index_col = 0)
# Iterate over rows of cars
for lab, row in cars.iterrows():
  print(lab + ": "+ row["country"])
# Out:
# US: United States
# AUS: Australia
# JAP: Japan
# IN: India
# RU: Russia
# MOR: Morocco
# EG: Egypt

# %%
for lab, row in cars.iterrows():

# %%
import numpy as np
np.random.rand()
# Out:
# 0.5136949195115946

# %%
import numpy as np
np.random.seed(123)
coin = np.random.randint(0,2)
coin
# Out:
# 0

# %%
import numpy as np
np.random.seed(123)
coin = np.random.randint(0,2)
print(coin)
if coin == 0:
  print("heads")
else:
  print("tails")
# Out:
# 0
# heads
