# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/kauan_lima/aula06_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dados=np.random.normal(20,200,2000)
dados
# Out:
# array([  87.318352  ,   72.34194398,  -77.57861359, ...,  -39.27487925,
#        -165.69270642,   42.25571793])

# %%
plt.hist(dados)
# Out:
# (array([  6.,  27., 109., 311., 503., 500., 357., 142.,  38.,   7.]),
#  array([-6.81236761e+02, -5.45029396e+02, -4.08822031e+02, -2.72614665e+02,
#         -1.36407300e+02, -1.99935069e-01,  1.36007430e+02,  2.72214795e+02,
#          4.08422160e+02,  5.44629526e+02,  6.80836891e+02]),
#  <BarContainer object of 10 artists>)

# %%
dados2=np.random.randint(20, 50,500)
print(dados2)
# Out:
# [31 31 34 20 30 47 38 46 26 36 43 23 30 34 22 39 30 48 27 29 41 36 33 33
#  44 46 37 36 39 30 32 48 33 26 38 48 23 34 29 40 47 47 21 42 38 26 20 22
#  28 21 47 33 37 36 47 20 48 24 43 21 39 40 20 23 45 25 33 40 23 33 31 21
#  35 30 31 32 39 21 39 35 41 33 29 35 45 28 33 26 26 27 48 33 26 29 47 21
#  46 32 39 20 30 41 34 22 34 23 44 39 27 25 22 30 29 36 32 28 25 22 44 30
#  22 37 42 32 35 26 29 26 47 25 33 23 47 26 45 23 21 36 45 39 47 31 46 30
#  27 41 22 27 36 26 20 41 44 26 25 34 43 45 36 23 49 25 41 38 39 48 29 25
#  42 20 36 33 35 45 44 34 30 28 45 40 39 23 27 34 34 39 33 42 25 26 33 24
#  47 25 32 43 41 41 28 31 21 34 25 48 24 30 47 22 44 49 48 35 25 46 36 21
#  22 45 20 27 47 32 44 23 35 45 33 39 47 34 36 43 33 40 25 28 45 38 25 36
#  35 46 39 28 27 43 22 37 23 21 45 28 27 42 31 41 23 39 49 48 43 37 23 48
#  26 46 26 31 34 44 28 39 23 30 24 46 47 26 31 25 31 41 39 28 28 30 30 46
#  45 26 40 31 22 47 30 27 31 41 33 21 42 31 46 23 47 30 29 38 48 28 38 35
# ...

# %%
plt.hist(dados2)
# Out:
# (array([48., 50., 51., 64., 62., 44., 40., 46., 49., 46.]),
#  array([20. , 22.9, 25.8, 28.7, 31.6, 34.5, 37.4, 40.3, 43.2, 46.1, 49. ]),
#  <BarContainer object of 10 artists>)

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.
