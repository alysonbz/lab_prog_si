# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/Francisco_Gomes/atividade_26_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6972]
plt.plot(year, pop)
plt.show()

# %%
import matplotlib.pyplot as plt
year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6972]
plt.scatter(year, pop)
plt.show()

# %%
import matplotlib.pyplot as plt
year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6972]
plt.plot(year, pop)
plt.show()

print(year[-1], pop [-1])
# Out:
# 2010 6972

# %%
plt.scatter(year, pop)
plt.xscale('log')
plt.show()

# %%
import matplotlib.pyplot as plt
year = [2021, 2022, 2023, 2024]
pop = [49.0, 49.50, 50.20, 53.60]
plt.scatter(year, pop)
plt.show()

# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                  5.1               3.5  ...               0.2       0
# 1                  4.9               3.0  ...               0.2       0
# 2                  4.7               3.2  ...               0.2       0
# 3                  4.6               3.1  ...               0.2       0
# 4                  5.0               3.6  ...               0.2       0
# ..                 ...               ...  ...               ...     ...
# 145                6.7               3.0  ...               2.3       2
# 146                6.3               2.5  ...               1.9       2
# 147                6.5               3.0  ...               2.0       2
# 148                6.2               3.4  ...               2.3       2
# 149                5.9               3.0  ...               1.8       2
#
# [150 rows x 5 columns]

# %%
from matplotlib import pyplot as plt
plt.scatter(df['petal length (cm)'], df['petal width (cm)'],c=df['target'])

# %%
from matplotlib import pyplot as plt
plt.scatter(df['sepal width (cm)'], df['sepal length (cm)'],c=df['target'])

# %%
from matplotlib import pyplot as plt
plt.scatter(df['sepal length (cm)'], df['petal width (cm)'],c=df['target'])

# %%
from matplotlib import pyplot as plt
plt.scatter(df['petal width (cm)'], df['sepal length (cm)'],c=df['target'])

# %%
from matplotlib import pyplot as plt
idade = [18, 17, 15, 16, 16, 19, 17, 18, 18, 20, 15, 18, 21, 19]
plt.hist(idade, bins=5)
plt.show()

# %%
from matplotlib import pyplot as plt
values = [0.0,0.6,1.4,1.6,2.2,2.5,2.6,3.2,3.5,3.9,4.2,6]
plt.hist(values, bins=3)
plt.show()

# %%
import matplotlib.pyplot as plt
help(plt.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x: 'ArrayLike | Sequence[ArrayLike]', bins: 'int | Sequence[float] | str | None' = None, *, range: 'tuple[float, float] | None' = None, density: 'bool' = False, weights: 'ArrayLike | None' = None, cumulative: 'bool | float' = False, bottom: 'ArrayLike | float | None' = None, histtype: "Literal['bar', 'barstacked', 'step', 'stepfilled']" = 'bar', align: "Literal['left', 'mid', 'right']" = 'mid', orientation: "Literal['vertical', 'horizontal']" = 'vertical', rwidth: 'float | None' = None, log: 'bool' = False, color: 'ColorType | Sequence[ColorType] | None' = None, label: 'str | Sequence[str] | None' = None, stacked: 'bool' = False, data=None, **kwargs) -> 'tuple[np.ndarray | list[np.ndarray], np.ndarray, BarContainer | Polygon | list[BarContainer | Polygon]]'
#     Compute and plot a histogram.
#
#     This method uses `numpy.histogram` to bin the data in *x* and count the
# ...

# %%
values = [df['sepal width (cm)']]
plt.hist(values)
plt.show()

# %%
#histograma da sala
from matplotlib import pyplot as plt
idade = [18, 18, 19, 18, 18, 21, 18, 18, 18, 20, 19, 18, 21, 19]
plt.hist(idade)
plt.show()

# %%
from inspect import isdatadescriptor
from matplotlib import pyplot as plt
idades = [18, 18, 19, 18, 17, 17, 18, 18, 18, 20, 19, 18, 19, 19]
plt.hist(idades, bins=5)
plt.show()

# %%
#limpar o histograma
from inspect import isdatadescriptor
from matplotlib import pyplot as plt
idades = [18, 18, 19, 18, 17, 17, 18, 18, 18, 20, 19, 18, 19, 19]
plt.hist(idades, bins=5)
plt.clf()
plt.show()
plt.close()

# %%
#criando histograma de 20 colunas
from inspect import isdatadescriptor
from matplotlib import pyplot as plt
idades = [18, 18, 19, 18, 17, 17, 18, 18, 18, 20, 19, 18, 19, 19]
plt.hist(idades, bins=20)
plt.show()

# %%
#limpando histograma
from inspect import isdatadescriptor
from matplotlib import pyplot as plt
idades = [18, 18, 19, 18, 17, 17, 18, 18, 18, 20, 19, 18, 19, 19]
plt.hist(idades, bins=5)
plt.clf()
plt.show()
