# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/hugo_alexandre/aula9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
year = [1950, 1970,1990, 2018]
pop = [2.519, 3.692, 5.263, 6.972]
plt.plot(year, pop)
plt.show()

# %%
import matplotlib.pyplot as plt
year = [1950, 1970,1990, 2018]
pop = [2.519, 3.692, 5.263, 6.972]
plt.scatter(year, pop)
plt.show()

# %%
# atividade 1
# questao 1: Na linha 4 print os últimos itens de year e pop.
print(year[-1], pop[-1])
# Out:
# 2018 6.972

# %%
# questao 2: Importe o módulo pyplot como plt.
import matplotlib.pyplot as plt
# questao 3: Mostre os gráficos com a função show.
plt.show(plt.scatter(year, pop))

# %%
# atividade 2
import matplotlib.pyplot as plt
year = [2020, 2021, 2022, 2023, 2024, 2025]
weight = [50,52,53,54,57,60]

#questao 1: Print os últimos itens de ano e peso seu
print(year[-1], weight[-1])
# questao 2: Faça um plot em linhas atribuindo no eixo ano e no eixo y peso
plt.plot(year, weight)
# questao 3: exiba o grafico
plt.show()
# Out:
# 2025 60

# %%
# atividade 3
#questao 1:Altere a forma do gráfico da linha  2 para o tipo scatter
plt.scatter(year, weight)
# questao 2 Coloque os dados em escala logarítimica na linha 6 fazendo plt.xscale('log')
plt.xscale('log')

#questao 3 Termine o script com plt.show()
plt.show()

# %%
# atividade 4 importe a biblioteca pyplot da matplotlib como plt.
import matplotlib.pyplot as plt
year = [2020, 2021, 2022, 2023, 2024, 2025]
weight = [50,52,53,54,57,60]
# questao 2 Faça um scatter usando eixo x ano e eixo y peso seu.
plt.scatter(year, weight)
# mostre o grafico
plt.show()

# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
data = load_iris()
df = pd.DataFrame(data.data, columns = data.feature_names)
df['target'] = data.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
from matplotlib import pyplot as plt
plt.scatter(df['petal length (cm)'], df['petal width (cm)'], c=df['target'])

# %%
values = [8,0.6,1.4,1.6, 2.2,2.5,2.6,3.2,3.5,3.9,4.2,6]

plt.hist(values, bins=3)

plt.show()

# %%
idades = [15, 16, 16, 17, 15, 16, 17, 18, 17, 16, 15, 18, 17, 16, 15]

plt.hist(idades, bins=4)
# Out:
# (array([4., 5., 4., 2.]),
#  array([15.  , 15.75, 16.5 , 17.25, 18.  ]),
#  <BarContainer object of 4 artists>)

# %%
idades = [15, 16, 16, 17, 15, 16, 17, 18, 17, 16, 15, 18, 17, 16, 15, 19,19]

plt.hist(idades, bins=5)
plt.clf()
plt.hist(idades, bins=20)
plt.clf()

# %%
world = {"brazil":30.55, "canada":89.00, "mexico":76.87}
print(world["brazil"])

casa = {'sala': ['televisao', 'sofa'], 'quarto':['cama', 'abajur'], 'banheiro':['sabonete', 'chuveiro']}
print(casa['sala'])

#definition of contries and capital
countries = ['spain', 'france', 'germany', 'norway']
capitals = ['madrid', 'paris', 'berlin', 'oslo']

#from string in countries and capitals, create dictionary europe
europe = {'spain':'madrid','france':'paris', 'germany':'berlin', 'oslo':'norway'}
print (europe)
# Out:
# 30.55
# ['televisao', 'sofa']
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'oslo': 'norway'}

# %%
#Utilizando o método keys() de europe, print as chaves do dicionário.
europe = {'spain':'madrid','france':'paris', 'germany':'berlin', 'norway':'oslo'}
print(europe.keys())
#2) Print o valor contido em norway.
print(europe ['norway'])
# Out:
# dict_keys(['spain', 'france', 'germany', 'norway'])
# oslo

# %%
world = {"afghanistan": 30.55, "albania":2.77, "algeria":39.21}
print (world ["albania"])

world = {"afghanistan": 38.55, "albania":2.77, "algeria":39.21, "albania": 2.81}
print(world)
# Out:
# 2.77
# {'afghanistan': 38.55, 'albania': 2.81, 'algeria': 39.21}

# %%
world["sealand"] = 0.000027
print(world)

"sealand" in world
# Out:
# {'afghanistan': 38.55, 'albania': 2.81, 'algeria': 39.21, 'sealand': 2.7e-05}
# True

# %%
world["sealand"] = 0.000028
print(world)

del(world["sealand"])
print(world)
# Out:
# {'afghanistan': 38.55, 'albania': 2.81, 'algeria': 39.21, 'sealand': 2.8e-05}
# {'afghanistan': 38.55, 'albania': 2.81, 'algeria': 39.21}

# %%
# Definition of dictionary
europe = {
    'spain': 'madrid',
    'france': 'paris',
    'germany': 'berlin',
    'norway': 'oslo'
}

# Add italy to europe
europe['italy'] = 'rome'

# Print out italy in europe
if 'italy' in europe:
    print('Italy está presente:', europe['italy'])

# Add poland to europe
europe['poland'] = 'warsaw'

# Print europe
print(europe)
# Out:
# Italy está presente: rome
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
# Corrija o valor contido em ‘germany’ na linha 9. Atribua o valor correto, que é ‘berlim’ .
europe = {
    'spain': 'madrid',
    'france': 'paris',
    'germany': 'bonn',
    'norway': 'oslo',
    'italy': 'rome',
    'poland':'warsaw',
    'australia':'vienna'}

europe['germany'] = 'berlin'
# Delete a chave ‘australia’ que está indevidamente inclusa no dicionário.
del europe['australia']

# Print o dicionário completo.
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
# Acessando os elementos do dicionário europe, print ‘paris’ que pertece ao subdicionário ‘france’.
europe = {
    'spain': {'capital': 'madrid', 'population': 46.77},
    'france': {'capital': 'paris', 'population': 66.77},
    'germany': {'capital': 'berlin', 'population': 80.62},
    'norway': {'capital': 'oslo', 'population': 5.084}
}
# Crie um novo dicionário chamado data e inclua neste 'capital' e 'population'. Atribua, respectivamente 'rome' e 59.83.
data = {'capital': 'rome', 'population':59.83}
# Crie uma nova chave ‘Italy’ para eurole inclua data dentro da chave.
europe['italy'] = data
# Print europe.
print(europe)
# Out:
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.77}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}, 'italy': {'capital': 'rome', 'population': 59.83}}

# %%
dict = {

"country":["Brazil", "Russia", "India", "China", "South Africa"],

"capital":["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
"area": [8.516, 17.10, 3.286, 9.597, 1.221],

"population": [200.4, 143.5, 1252, 1357, 52.98]}

import pandas as pd

brics = pd.DataFrame(dict)

# %%
brics
brics.index = ("BR", "RU", "IN", "CH", "SA")

brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr = [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

# 1) Importe a biblioteca pandas como pd
import pandas as pd

# 2) Crie um dicionário chamado my_dict
my_dict = {
    'country': names,
    'drives_right': dr,
    'cars_per_cap': cpc
}

# 3) Crie um dataframe chamado cars a partir do dicionário
cars = pd.DataFrame(my_dict)

# 4) Print cars
print(cars)
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45

# %%
import pandas as pd

# Build cars DataFrame
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr = [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]
cars_dict = {
    'country': names,
    'drives_right': dr,
    'cars_per_cap': cpc
}
cars = pd.DataFrame(cars_dict)
print(cars)

# Definition of row_labels
row_labels = ['US', 'AUS', 'JPN', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index = row_labels

# Print cars again
print(cars)
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45
#            country  drives_right  cars_per_cap
# US   United States          True           809
# AUS      Australia         False           731
# JPN          Japan         False           588
# IN           India         False            18
# RU          Russia          True           200
# MOR        Morocco          True            70
# EG           Egypt          True            45

# %%
# 2) Importe a biblioteca pandas
import pandas as pd

# 3) Leia o arquivo CSV e crie a variável cars
cars = pd.read_csv('cars.csv')

# 4) Print cars
print(cars)

# %%
import pandas as pd

cars = pd.read_csv('cars.csv', index_col=0)

print(cars)

# %%
brics ["country"]
# Out:
# 0          Brazil
# 1          Russia
# 2           India
# 3           China
# 4    South Africa
# Name: country, dtype: object

# %%
type(brics["country"])
# Out:
# pandas.core.series.Series

# %%
type (brics[["country"]])
# Out:
# pandas.core.frame.DataFrame

# %%
brics[["country", "capital"]]
# Out:
#         country    capital
# 0        Brazil   Brasilia
# 1        Russia     Moscow
# 2         India  New Delhi
# 3         China    Beijing
# 4  South Africa   Pretoria

# %%
brics[1:4]
# Out:
#   country    capital    area  population
# 1  Russia     Moscow  17.100       143.5
# 2   India  New Delhi   3.286      1252.0
# 3   China    Beijing   9.597      1357.0

# %%
brics.loc["RU"]
# Out:
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: RU, dtype: object

# %%
brics.loc[["RU"]]
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %%
brics.loc[["RU", "IN", "CH"]]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
brics.loc[["RU", "IN", "CH"], ["country", "capital"]]
# Out:
#    country    capital
# RU  Russia     Moscow
# IN   India  New Delhi
# CH   China    Beijing

# %%
brics.loc[:, ["country", "capital"]]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %%
brics.loc[["RU"]]
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %%
brics.iloc[[1]]
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %%
brics.iloc[[1,2,3]]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
brics.iloc[[1,2,3], [0,1]]
# Out:
#    country    capital
# RU  Russia     Moscow
# IN   India  New Delhi
# CH   China    Beijing
