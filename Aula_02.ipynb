# %% [markdown]
# segunda aula

# %%
fam = [1.80, 1.75, 1,64, 1.74]
fam
# Out:
# [1.8, 1.75, 1, 64, 1.74]

# %%
alunos =  ['João', 'Jose', 'Wesley']
print(alunos)
# Out:
# ['João', 'Jose', 'Wesley']

# %%
alunos.append('Habacuqui')
print(alunos)
# Out:
# ['João', 'Jose', 'Wesley', 'Habacuqui']

# %%
aluno_notas = [['Alice',2], ['Jose',3],['James',10]]
print(aluno_notas)
# Out:
# [['Alice', 2], ['Jose', 3], ['James', 10]]
