# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/joao_pedro/Aula_gr%C3%A1fico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
anos = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]
plt.plot(anos, pop)
plt.title('População x Ano')
plt.xlabel('Ano')
plt.ylabel('População')
plt.show()

# %%
print(anos[-1])
print(pop[-1])
# Out:
# 2010
# 6.972

# %%
ano = [2020, 2021, 2022, 2023, 2024, 2025]
peso = [67, 70, 72, 75, 77, 78]
plt.plot(ano, peso)
plt.show()

# %%
plt.scatter(ano, peso)
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                  5.1               3.5  ...               0.2       0
# 1                  4.9               3.0  ...               0.2       0
# 2                  4.7               3.2  ...               0.2       0
# 3                  4.6               3.1  ...               0.2       0
# 4                  5.0               3.6  ...               0.2       0
# ..                 ...               ...  ...               ...     ...
# 145                6.7               3.0  ...               2.3       2
# 146                6.3               2.5  ...               1.9       2
# 147                6.5               3.0  ...               2.0       2
# 148                6.2               3.4  ...               2.3       2
# 149                5.9               3.0  ...               1.8       2
#
# [150 rows x 5 columns]

# %%
plt.scatter(df['petal length (cm)'], df['petal width (cm)'], c=df['target'])
plt.show()

# %%
plt.scatter(df['sepal length (cm)'], df['petal width (cm)'], c=df['target'], cmap='viridis')
plt.show()

# %%
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'], cmap='viridis')
plt.show()

# %%
plt.scatter(df['petal length (cm)'], df['sepal width (cm)'], c=df['target'], cmap='viridis')
plt.show()

# %%
plt.scatter(df['petal length (cm)'], df['sepal length (cm)'], c=df['target'], cmap='viridis')
plt.show()

# %%
plt.scatter(df['petal width (cm)'], df['sepal width (cm)'], c=df['target'], cmap='viridis')
plt.show()

# %%
plt.scatter(df['sepal width (cm)'], df['petal width (cm)'], c=df['target'], cmap='viridis')
plt.show()

# %%
idades_sala = [5,18,18,18,18,18,18,18,19,19, 20]
plt.hist(idades_sala, bins=33)
plt.show()

# %%
plt.hist(df['sepal width (cm)'], bins=50)
plt.show()

# %%
world = {'Afeganistão':30.55, 'Albania':2.81, 'Argelia':39.21}

# %%
world['Sealand'] = 0.000028
world
# Out:
# {'Afeganistão': 30.55, 'Albania': 2.81, 'Argelia': 39.21, 'Sealand': 2.8e-05}

# %%
del(world['Sealand'])
world
# Out:
# {'Afeganistão': 30.55, 'Albania': 2.81, 'Argelia': 39.21}

# %%
europa = {'Spain':'Mardri', 'France':'Paris', 'Germany':'Berlin', 'Norway':'Oslo'}

# %%
europa['Italy'] = 'Rome'
europa
# Out:
# {'Spain': 'Mardri',
#  'France': 'Paris',
#  'Germany': 'Berlin',
#  'Norway': 'Oslo',
#  'Italy': 'Rome'}

# %%
'Italy' in europa
# Out:
# True
