# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/levi_nascimento/Aula_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PANDAS

# %%
dict = {

"country":["Brazil", "Russia", "India", "China", "South Africa"],
"capital":["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
"area": [8.516, 17.10, 3.286, 9.597, 1.221],
"population":[200.4, 143.5, 1252, 1357, 52.98]}

# %%
import pandas as pd
brics = pd.DataFrame(dict)
brics
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia   8.516      200.40
# 1        Russia     Moscow  17.100      143.50
# 2         India  New Delhi   3.286     1252.00
# 3         China    Beijing   9.597     1357.00
# 4  South Africa   Pretoria   1.221       52.98

# %%
brics.index = ["BR", "RU", "IN", "CH", "SA"]
brics #.index, identificar as linhas
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# PRATIQUE

# %%
#121
import pandas as pd

names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morroco', 'Egypt']
dr = [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

#Crie um dicionário chamado my_dict considerando 3 chaves :
my_dict = {
    'country': names,
    'drives_right': dr,
    'cars_pep_cap': cpc
}
#Crie um dataframe chamado cars a partir do dicionário.

cars = pd.DataFrame(my_dict)

#print cars

cars
# Out:
#          country  drives_right  cars_pep_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morroco          True            70
# 6          Egypt          True            45

# %%
#122
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morroco', 'Egypt']
dr = [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]
my_dict = {
    'country': names,
    'drives_right': dr,
    'cars_pep_cap': cpc
}
cars = pd.DataFrame(my_dict)
print(cars)

#Especifique a coluna index baseada na lista row_labels.
row_labels = ['US', 'AUS', 'JPN', 'IN', 'RU', 'MOR', 'EG']
cars.index = row_labels

#print
cars
# Out:
#          country  drives_right  cars_pep_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morroco          True            70
# 6          Egypt          True            45
#            country  drives_right  cars_pep_cap
# US   United States          True           809
# AUS      Australia         False           731
# JPN          Japan         False           588
# IN           India         False            18
# RU          Russia          True           200
# MOR        Morroco          True            70
# EG           Egypt          True            45

# %%
#123
import pandas as pd

#Importe a biblioteca pandas
#Crie uma variável cars e leia o arquivo .csv
#Print cars

cars = pd.read_csv('/content/sample_data/cars.csv')
cars
# Out:
#   country_ab  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %%
#corrija a leitura do .csv incluindo o index_col = 0
cars = pd.read_csv('/content/sample_data/cars.csv', index_col = 0)
print(cars)
# Out:
#             cars_per_cap        country  drives_right
# country_ab
# US                   809  United States          True
# AUS                  731      Australia         False
# JAP                  588          Japan         False
# IN                    18          India         False
# RU                   200         Russia          True
# MOR                   70        Morocco          True
# EG                    45          Egypt          True

# %% [markdown]
# Acesso

# %%
brics['country']
# Out:
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# SA    South Africa
# Name: country, dtype: object

# %%
type(brics['country'])
# Out:
# pandas.core.series.Series

# %%
brics[['country']] #vira um dataframe
print(brics)
type(brics)
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98
# pandas.core.frame.DataFrame

# %%
brics[['country', 'capital']]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %%
brics[1:4]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
brics.loc["RU"] #Acessar a Linha
# Out:
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: RU, dtype: object

# %%
brics.loc[["RU", "IN", "CH"]]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
brics.loc[["RU", "IN", "CH"], ['country', 'capital']]
# Out:
#    country    capital
# RU  Russia     Moscow
# IN   India  New Delhi
# CH   China    Beijing

# %%
brics.loc[:, ['country', 'capital']] #Todas as linhas de country e capital
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %%
brics.loc[["RU"]]
brics.iloc[[1]] #iloc acessa pelo número da linha
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %%
brics.iloc[[1, 2, 3], [0,1]]
# Out:
#    country    capital
# RU  Russia     Moscow
# IN   India  New Delhi
# CH   China    Beijing

# %%
from sklearn.datasets import load_wine

data_wine = load_wine()
df_wine = pd.DataFrame (data_wine.data, columns = data_wine.feature_names)
y = data_wine.target
df_wine['target'] = y
df_wine
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df_wine[['alcohol', 'ash']]
# Out:
#      alcohol   ash
# 0      14.23  2.43
# 1      13.20  2.14
# 2      13.16  2.67
# 3      14.37  2.50
# 4      13.24  2.87
# ..       ...   ...
# 173    13.71  2.45
# 174    13.40  2.48
# 175    13.27  2.26
# 176    13.17  2.37
# 177    14.13  2.74
#
# [178 rows x 2 columns]

# %%
df_wine[1:4]
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
#
#    od280/od315_of_diluted_wines  proline  target
# 1                          3.40   1050.0       0
# 2                          3.17   1185.0       0
# 3                          3.45   1480.0       0

# %%
df_wine.loc[150] #Acessar a Linha
# Out:
# alcohol                          13.50
# malic_acid                        3.12
# ash                               2.62
# alcalinity_of_ash                24.00
# magnesium                       123.00
# total_phenols                     1.40
# flavanoids                        1.57
# nonflavanoid_phenols              0.22
# proanthocyanins                   1.25
# color_intensity                   8.60
# hue                               0.59
# od280/od315_of_diluted_wines      1.30
# proline                         500.00
# target                            2.00
# Name: 150, dtype: float64

# %%
brics.iloc[[1, 2, 3]]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
from matplotlib import pyplot as plt
plt.scatter(df_wine['alcohol'], df_wine['malic_acid'], c=df_wine['target'])
