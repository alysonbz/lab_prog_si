# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/habacuquidoglas/aula_revis%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dados = np.random.normal(20,200,2000)
dados
# Out:
# array([  59.90971851, -272.8595235 , -119.46443263, ...,  132.97130216,
#         400.90044589,  -13.53152282])

# %%
plt.hist(dados)
# Out:
# (array([  6.,  19.,  90., 250., 469., 521., 408., 180.,  47.,  10.]),
#  array([-703.36068275, -565.90267399, -428.44466522, -290.98665646,
#         -153.5286477 ,  -16.07063894,  121.38736982,  258.84537859,
#          396.30338735,  533.76139611,  671.21940487]),
#  <BarContainer object of 10 artists>)

# %%
dados2 = np.random.randint(20,200,2000)
dados2
# Out:
# array([115, 161, 128, ..., 100, 107,  98])

# %%
plt.hist(dados2)
# Out:
# (array([208., 178., 196., 205., 198., 207., 231., 180., 185., 212.]),
#  array([ 20. ,  37.9,  55.8,  73.7,  91.6, 109.5, 127.4, 145.3, 163.2,
#         181.1, 199. ]),
#  <BarContainer object of 10 artists>)

# %%
x["a","b","c","d"]
