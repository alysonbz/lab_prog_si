# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/levi_nascimento/Aula_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GRÁFICOS

# %% [markdown]
# MATPLOTLIB-PLOT

# %%
import matplotlib.pyplot as plt
ano = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]
plt.plot(ano, pop)
plt.show()

# %%
ano = [2020, 2021, 2022, 2023, 2024, 2025]
peso = [80, 85, 83, 84, 88, 85]
plt.plot(ano, peso)
plt.show()

# %%
#Scatter - ponto de cada coordenada
ano = [2020, 2021, 2022, 2023, 2024, 2025]
peso = [80, 85, 83, 84, 88, 85]
plt.scatter(ano, peso)
plt.show()

# %% [markdown]
# PRATIQUE

# %%
#85

ano = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]

#1) print os últimos itens de year e pop.
print(ano[-1], pop[-1])

#2) Importe o módulo pyplot como plt.
import matplotlib.pyplot as plt

#3) Mostre os gráficos com a função show.
plt.plot(ano, pop)
plt.show()
# Out:
# 2010 6.972

# %%
#86

ano = [2020, 2021, 2022, 2023, 2024, 2025]
peso = [80, 85, 83, 84, 88, 85]

#1)Print os últimos itens de ano e peso seu
print(ano[-1], peso[-1])

#2)Faça um plot em linhas atribuindo no eixo ano e no eixo y peso
plt.plot(ano, peso)

#3)Exiba o gráfico
plt.show()
# Out:
# 2025 85

# %%
#87

ano = [2020, 2021, 2022, 2023, 2024, 2025]
peso = [80, 85, 83, 84, 88, 85]

#1)Altere a forma do gráfico da linha  2 para o tipo scatter
plt.scatter(ano, peso)

#2)Coloque os dados em escala logarítimica na linha 6 fazendo plt.xscale('log')
plt.xscale('log')

#3)Termine o script com plt.show()
plt.show()

# %%
#88

ano = [2020, 2021, 2022, 2023, 2024, 2025]
peso = [80, 85, 83, 84, 88, 85]

#1)importe a biblioteca pyplot da matplotlib como plt.
import matplotlib.pyplot as plt

#2) Faça um scatter usando eixo x ano e eixo y peso seu.
plt.scatter(ano, peso)

#3)Mostre o grafico.
plt.show()

# %% [markdown]
# EM sala, análise

# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
from matplotlib import pyplot as plt

plt.scatter(df['petal length (cm)'], df['petal width (cm)'], c=df['target'])

# %%
from matplotlib import pyplot as plt

plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'])

# %%
from matplotlib import pyplot as plt

plt.scatter(df['sepal length (cm)'], df['petal length (cm)'], c=df['target'])

# %%
from matplotlib import pyplot as plt

plt.scatter(df['sepal length (cm)'], df['petal width (cm)'], c=df['target'])

# %%
from matplotlib import pyplot as plt

plt.scatter(df['sepal width (cm)'], df['petal length (cm)'], c=df['target'])

# %%
from matplotlib import pyplot as plt

plt.scatter(df['sepal width (cm)'], df['petal width (cm)'], c=df['target'])

# %% [markdown]
# Gráfico para estatística
# histograma - indica a quantidadede de ocorrência dos elementos

# %%
import matplotlib.pyplot as plt
values = [0, 0.6, 1.4, 2.2, 2.5, 2.6, 3.2, 3.5, 3.9, 4,2, 6]
plt.hist(values, bins = 3)
plt.show()

# %%
import matplotlib.pyplot as plt
values = [18, 18, 18, 18, 19, 19, 18, 20, 5, 18, 18]
plt.hist(values, bins = 3)
plt.show()

# %%
plt.hist(df['sepal width (cm)'], bins = 150) #bins quantidades de barra que voc~e quer exibir
plt.show()

# %% [markdown]
# PRATIQUE

# %%
#1)Crie um histograma de uma lista de idade dos alunos da sala de aula.
idades = [18, 18, 18, 18, 19, 19, 18, 20, 5, 18, 18, 20, 21, 19, 18, 18, 19, 20, 21, 18]

#2) Mostre o histograma
plt.hist(idades, bins = 10)
plt.show()

# %%
#Crie um histograma com 5 barras (bins) da lista de idades
plt.hist(idades, bins = 5)

#Mostre o histograma na linha 5 e na linha 6 faça plt.clf() para limpar o gráfico.
plt.show()
plt.clf()

#Faça um novo histograma de 20 colunas
#Mostre e limpe o gráfico novamente.
plt.hist(idades, bins = 20)
plt.clf()
plt.show()

# %% [markdown]
# CUSTOMIZAÇÃO DE GRÁFICOS

# %%
import matplotlib.pyplot as plt

ano = [2020, 2021, 2022, 2023, 2024, 2025]
peso = [80, 85, 83, 84, 88, 85]

plt.plot(ano, peso)

plt.xlabel("Ano") #label- seria a fórmula de rotular
plt.ylabel("Peso")
plt.title("Crescimemto da massa muscular")
plt.yticks([80, 82, 84, 86, 88, 90],
           ['perfeito', 'vixi aumentou', 'o que tá fazendo?', 'para de comer', 'Só aceita', 'Obesidade'])

plt.show()

# %% [markdown]
# PRATIQUE -  utilize o peso de vocês nos últimos 5 anos.

# %%
import matplotlib.pyplot as plt

ano = [2020, 2021, 2022, 2023, 2024, 2025]
peso = [80, 85, 83, 84, 88, 85]

# 1) Adicione legendas para os eixos x e y utilizando as strings ylab e xlab.

plt.plot(ano, peso)

plt.xlabel("Ano")
plt.ylabel("Idade")

#2)Adicione o título utilizando a string title.

plt.title('Aumento de Massa corporal')

#3) Por fim, mostre o gráfico customizado.

plt.show()

# %%
#Faça a marcação do eixo x usando a função xticks, utilizando tick_val e tick_lab.

ano = [2020, 2021, 2022, 2023, 2024, 2025]
peso = [80, 85, 83, 84, 88, 85]

plt.plot(ano, peso)

plt.xlabel("Ano")
plt.ylabel("Idade")

plt.title('Aumento de Massa corporal')

#Faça a marcação do eixo x usando a função xticks, utilizando tick_val e tick_lab.
#Mostre o gráfico gerado
plt.xticks([2020, 2022, 2024, 2026])
plt.yticks([80, 82, 84, 86, 88, 90])
# Out:
# ([<matplotlib.axis.YTick at 0x7cfd402a48d0>,
# ...
#  [Text(0, 80, '80'),
#   Text(0, 82, '82'),
#   Text(0, 84, '84'),
#   Text(0, 86, '86'),
#   Text(0, 88, '88'),
#   Text(0, 90, '90')])

# %% [markdown]
# DICIONÁRIOS

# %%
pop = [30.55, 2.77, 39.21]
countries = ["Afeganistão", "Albania", "Algeria"]

world = {"Afeganistão":30.55, "Albania":2.77, "Algeria":39.21}
world["Albania"]
# Out:
# 2.77

# %%
"Afeganistão" in world
world['Afeganistão']=45.60 #Substituir no dicionario
world
# Out:
# {'Afeganistão': 45.6, 'Albania': 2.77, 'Algeria': 39.21}

# %%
#exclusão de chave
del(world["Albania"])
world
# Out:
# {'Afeganistão': 45.6, 'Algeria': 39.21}

# %% [markdown]
# Criar um dicionário com os ambientes da sua casa

# %%
casa = {"Sala": ["TV", "Sofá", "Armário"],
        "Quarto": ["Cama", "Ventilador", "Mesa"],
        "Cozinha": ["Fogão", "Geladeira", "Bebedouro"]}
print(casa)
# Out:
# {'Sala': ['TV', 'Sofá', 'Armário'], 'Quarto': ['Cama', 'Ventilador', 'Mesa'], 'Cozinha': ['Fogão', 'Geladeira', 'Bebedouro']}

# %% [markdown]
# PRATIQUE

# %%
#Termine o dicionário europe na linha 6 e print seus elementos na linha 9.

paises = ['spain', 'france', 'germany', 'norway']
capitais = ['madrid', 'paris', 'berlin', 'oslo']

europe = {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo'}
europe
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo'}

# %% [markdown]
# PRATIQUE

# %%
europe = {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo'}
europe

#Crie uma nova chave para o dicionário europe chamada ‘italy’ e inclua o valor ‘rome’. Na linha 7
europe['italy'] = 'rome'

#verifique se ‘italy’ está presente em europe e print a análise.Na linha 10.
print('italy' in europe)

#Crie uma nova chave para o dicionário europe chamada ‘poland’ e inclua o valor ‘warsaw’. Na linha 13.
europe['poland'] = 'warsaw'

#print o dicionário europe completo.
print(europe)
# Out:
# True
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
europe = {'spain': 'madrid', 'france': 'paris', 'germany': 'bonn', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsal', 'australia': 'vienna'}


#Corrija o valor contido em ‘germany’ na linha 9. Atribua o valor correto, que é ‘berlim’ .
europe['germany'] = 'berlim'

#Delete a chave ‘australia’ que está indevidamente inclusa no dicionário.
del(europe['australia'])

#print o dicionario completo
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlim', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsal'}

# %%
europe = {'spain': { 'capital':'madrid', 'population':46.77 },
          'france': { 'capital':'paris', 'population':66.03},
          'germany': { 'capital': 'berlin', 'population': 80.62},
          'norway': { 'capital':'oslo', 'population':5.084}}

#Acessando os elementos do dicionário europe, print ‘paris’ que pertece ao subdicionário ‘france’.
print(europe['france'])

#Crie um novo dicionário chamado data e inclua neste 'capital' e 'population'. Atribua, respectivamente 'rome' e 59.83.
data= {'capital': 'rome', 'population': 59.83}

#Crie uma nova chave ‘Italy’ para europe e inclua data dentro da chave.
#Print europe.
europe['italy'] = data

print(europe)
# Out:
# {'capital': 'paris', 'population': 66.03}
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.03}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}, 'italy': {'capital': 'rome', 'population': 59.83}}
