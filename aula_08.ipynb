# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/laisa_gomes/aula_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
countries = ['spain', 'france', 'germany', 'norway']
capitals  = ['madrid', 'paris', 'berlin', 'oslo']

europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo'}

print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo'}

# %%
#Utilizando o método keys() de europe, print as chaves do dicionário.
print(europe.keys())
print(europe.values())
# Out:
# dict_keys(['spain', 'france', 'germany', 'norway'])
# dict_values(['madrid', 'paris', 'berlin', 'oslo'])

# %%
#Print o valor contido em norway.
print(europe['norway'])
# Out:
# oslo

# %%
#Crie uma nova chave para o dicionário europe chamada ‘italy’ e inclua o valor ‘rome’.
europe['italy'] = 'rome'
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome'}

# %%
# Na linha 7 verifique se ‘italy’ está presente em europe e print a análise.
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome'}

# %%
#Na linha 10 crie uma nova chave para o dicionário europe chamada ‘poland’ e inclua o valor ‘warsaw’.
europe['poland'] = 'warsaw'
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlim', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
#Na linha 13 print o dicionário europe completo.
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlim', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
europe['australia'] = 'vienna'

# %%
#Corrija o valor contido em ‘germany’ na linha 9. Atribua o valor correto, que é ‘berlim’
europe['germany'] = 'berlim'
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlim', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
#Delete a chave ‘australia’ que está indevidamente inclusa no dicionário
del europe['australia']
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlim', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
#Print o dicionário completo
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlim', 'norway': 'oslo', 'italy': 'rome'}

# %%
europe = {'spain': {'capital':'madrid', 'population':46.77},
          'france': {'capital':'paris', 'population':66.03},
          'germany': {'capital':'berlin', 'population':80.62},
          'norway': {'capital':'oslo', 'population':5.084} }
#Acessando os elementos do dicionário europe, print ‘paris’ que pertece ao subdicionário ‘france’.
print(europe['france']['capital'])
# Out:
# paris

# %%
#Crie um novo dicionário chamado data e inclua neste 'capital' e 'population'. Atribua, respectivamente 'rome' e 59.83.
data = {'capital':'rome', 'population':59.83}
# Out:
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.03}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}}

# %%
#Crie uma nova chave ‘Italy’ para europe e inclua data dentro da chave.
europe['italy'] = data

# %%
print(europe)
# Out:
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.03}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}, 'italy': {'capital': 'rome', 'population': 59.83}}
