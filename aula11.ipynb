# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/Emanuel_Oliveira/aula11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pandas

# %%
import pandas as pd
dict = {
    "country":["brazil", "russia", "india", "china", "america do sul"],
    "capital":["brasilia", "moscou", "nova dhlei", "beijing", "pretoria"],
    "area":[8.516,17.10,3.286,9.597,1.221],
    "population":[200.4,143.5,1252,1357,52.98]
}
brics = pd.DataFrame(dict)
brics
# Out:
#           country     capital    area  population
# 0          brazil    brasilia   8.516      200.40
# 1          russia      moscou  17.100      143.50
# 2           india  nova dhlei   3.286     1252.00
# 3           china     beijing   9.597     1357.00
# 4  america do sul    pretoria   1.221       52.98

# %%
brics.index = ["BR","RU","IN","CH","SA"]
brics
# Out:
#            country     capital    area  population
# BR          brazil    brasilia   8.516      200.40
# RU          russia      moscou  17.100      143.50
# IN           india  nova dhlei   3.286     1252.00
# CH           china     beijing   9.597     1357.00
# SA  america do sul    pretoria   1.221       52.98

# %%
brics = pd.read_csv("/content/cars.csv", index_col = 0)
brics
# Out:
#             cars_per_cap        country  drives_right
# country_ab
# US                   809  United States          True
# AUS                  731      Australia         False
# JAP                  588          Japan         False
# IN                    18          India         False
# RU                   200         Russia          True
# MOR                   70        Morocco          True
# EG                    45          Egypt          True

# %%
brics["country"]
# Out:
# country_ab
# US     United States
# AUS        Australia
# JAP            Japan
# IN             India
# RU            Russia
# MOR          Morocco
# EG             Egypt
# Name: country, dtype: object

# %%
type(brics["country"])
# Out:
# pandas.core.series.Series

# %%
brics[["country"]]
# Out:
#                   country
# country_ab
# US          United States
# AUS             Australia
# JAP                 Japan
# IN                  India
# RU                 Russia
# MOR               Morocco
# EG                  Egypt

# %%
brics[["country","capital"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-41-2020235797.py in <cell line: 0>()
# ----> 1 brics[["country","capital"]]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %%
brics[1:4]
# Out:
#             cars_per_cap    country  drives_right
# country_ab
# AUS                  731  Australia         False
# JAP                  588      Japan         False
# IN                    18      India         False

# %%
brics.loc[["RU"]]
# Out:
#             cars_per_cap country  drives_right
# country_ab
# RU                   200  Russia          True

# %%
brics.loc[["RU","IN",],["country",]]
# Out:
#            country
# country_ab
# RU          Russia
# IN           India

# %%
brics.loc[:,["country"]]
# Out:
#                   country
# country_ab
# US          United States
# AUS             Australia
# JAP                 Japan
# IN                  India
# RU                 Russia
# MOR               Morocco
# EG                  Egypt

# %%
brics.loc[["RU"]]
# Out:
#             cars_per_cap country  drives_right
# country_ab
# RU                   200  Russia          True

# %%
brics.iloc[[1,2,3],[0,1]]
# Out:
#             cars_per_cap    country
# country_ab
# AUS                  731  Australia
# JAP                  588      Japan
# IN                    18      India

# %% [markdown]
# 1)importe a biblioteca pandas como pd
#
# 2)Crie um dicionário chamado my_dict considerando 3 chaves:
#
# key 'country' e value names.
#
# key 'drives_right'  e value dr.
#
# key 'cars_per_cap' and value cpc.
#
# 3)Crie um dataframe chamado cars a partir do dicionário.
#
# 4)Print cars

# %%
# Pre-defined lists
names = ['United States', 'Australia', 'Japan', 'India', 'Russia' 'Morocco', 'Egypt']
dr = [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]
# Import pandas as pd
import pandas as pd
# Create dictionary my_dict with three key:value pairs: my_dict
my_dict = {
    "country":[names],
    "drivers_right":[dr],
    "cars_per_cap":[cpc]
          }
# Build a DataFrame cars from my_dict: cars
cars = pd.DataFrame(my_dict)
# Print cars
cars
# Out:
#                                              country  \
# 0  [United States, Australia, Japan, India, Russi...
#
#                                    drivers_right  \
# 0  [True, False, False, False, True, True, True]
#
#                        cars_per_cap
# 0  [809, 731, 588, 18, 200, 70, 45]

# %% [markdown]
# 1)Especifique a coluna index baseada na lista row_labels.
#
# 2)Print cars novamente

# %%
import pandas as pd
# Build cars DataFrame
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr = [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]
cars_dict = { 'country': names, 'drives_right':dr, 'cars_per_cap':cpc}
cars = pd.DataFrame (cars_dict)
print(cars)
# Definition of row_labels
row_labels = ['US', 'AUS', 'JPN', 'IN', 'RU', 'MOR', 'EG']
# Specify row labels of cars
cars.index = row_labels
# Print cars again
cars
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45
#            country  drives_right  cars_per_cap
# US   United States          True           809
# AUS      Australia         False           731
# JPN          Japan         False           588
# IN           India         False            18
# RU          Russia          True           200
# MOR        Morocco          True            70
# EG           Egypt          True            45

# %% [markdown]
# 1)Adicione este arquivo .csv na página do colab.
#
# https://drive.google.com/file/d/1kp1WzC5JojaWuj_HuSWni61Upsa1N9bo/view?usp=sharing
#
# 2)Importe a biblioteca pandas
#
# 3)Crie uma variável cars e leia o arquivo .csv
#
# 4)Print cars

# %%
#import panda as pd
import pandas as pd
#import the cars.csv data: cars
cars = pd.read_csv("/content/cars.csv", index_col = 0)
#print out cars
cars
# Out:
#             cars_per_cap        country  drives_right
# country_ab
# US                   809  United States          True
# AUS                  731      Australia         False
# JAP                  588          Japan         False
# IN                    18          India         False
# RU                   200         Russia          True
# MOR                   70        Morocco          True
# EG                    45          Egypt          True

# %% [markdown]
# 1)corrija a leitura do .csv incluindo o index_col = 0

# %%
# Import pandas as pd
import pandas as pd
# Fix import by including index_col
cars = pd.read_csv('cars.csv')
# Print out cars
print(cars)
# Out:
#   country_ab  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %%
#########corrigido##########
# Import pandas as pd
import pandas as pd
# Fix import by including index_col
cars = pd.read_csv('cars.csv', index_col = 0)
# Print out cars
print(cars)
# Out:
#             cars_per_cap        country  drives_right
# country_ab
# US                   809  United States          True
# AUS                  731      Australia         False
# JAP                  588          Japan         False
# IN                    18          India         False
# RU                   200         Russia          True
# MOR                   70        Morocco          True
# EG                    45          Egypt          True

# %%
from sklearn.datasets import load_wine
data_wine = load_wine()
df_wine = pd.DataFrame(data_wine.data, columns = data_wine.feature_names)
y = data_wine.target
df_wine["target"] = y
df_wine
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
from matplotlib import pyplot as plt
plt.scatter(df_wine["alcohol"], df_wine["target"], df_wine["malic_acid"])
