# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/hugo_alexandre/aula11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
True and True
# Out:
# True

# %%
x = 12
x > 5 and x <15
# TRUE      TRUE
# Out:
# True

# %%
False and True
# Out:
# False

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
y = 5
y < 7 or y > 13
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
import numpy as np

np_height = np.array([1.73, 1.68, 1.71, 1.89, 1.79])

np_weight = np.array([65.4, 59.2, 63.6, 88.4, 68.7])

bmi = np_weight / np_height ** 2

bmi
# Out:
# array([21.85171573, 20.97505669, 21.75028214, 24.7473475 , 21.44127836])

# %%
bmi > 21
# Out:
# array([ True, False,  True,  True,  True])

# %%
bmi < 22
# Out:
# array([ True,  True,  True, False,  True])

# %%
bmi > 21 and bmi < 22

# %%
np.logical_and(bmi>21, bmi < 22)
# Out:
# array([ True, False,  True, False,  True])

# %%
bmi[np.logical_and(bmi>21, bmi < 22)]
# Out:
# array([21.85171573, 21.75028214, 21.44127836])

# %%
# verifique se my_kitchen é maior que 10 e menor que 18.
my_kitchen = 18.0
your_kitchen = 14.0
np.logical_and(my_kitchen > 10, my_kitchen < 18)
# Out:
# np.False_

# %%
# verifique se my_kitchen é menor que 14 e menor que 17.
np.logical_and(my_kitchen < 14, my_kitchen < 17)
# Out:
# np.False_

# %%
# Verifique se o dobro de my_kitchen é menor que o triplo de your_kitchen.
2*my_kitchen < 3*your_kitchen
# Out:
# True

# %%
# verifique quais elementos de my_house são maiores que 18.5 ou menores que 10.
import numpy as np
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0,24.0,14.25,9.0])

print(np.logical_or(my_house > 18.5, my_house< 10))
# Verifique quis elementos das mesmas posições dos arrays possuem valor menor que 11.
print(np.logical_and(my_house<11, your_house<11))
# Out:
# [False  True False  True]
# [False False False  True]

# %%
z = 4

if z % 2 ==0:
  print("checking" + str(z))
print("z is even")
# Out:
# checking4
# z is even

# %%
z = 5

if z% 2 == 0 :


  print("checking" + str(z))

  print("z is even")

# %%
z = 5

if z% 2 == 0:


  print("z is even")

else:

  print("z is odd")
# Out:
# z is odd

# %%
z=3

if z%2==0:

  print("z is divisible by 2")



elif z% 3==0:

  print("z is divisible by 3")

else:

 print("z is neither divisible by 2 nor by 3")
# Out:
# z is divisible by 3

# %%
room = "kit"
area= 14

#na linha 10 verifique que se area for
#maior que 15 print a mensage : “BigPLace”
if room== "kit":
  print("looking around in the kitchen.")

if area>15:
 print("bigplace")
else:
  print("pretty small")
#2) Apos á verificação, utilize o comando
#else para informar que se caso
#contrário, print “pretty small”.
# Out:
# looking around in the kitchen.
# pretty small
